# %% [markdown]
# # Python for (open) Neuroscience
#
# _Lecture 0.0.0 - Introduction to Python_
#
# Luigi Petrucco
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vigji/python-cimec-2025/blob/main/lectures/Lecture0.0.0_Introduction.ipynb)

# %% [markdown]
# ## Lecture outline
#
#  - Course organization business
#  - General introduction to Python
#  - Introduction to Python syntax
#  - Variables and types

# %% [markdown]
# ### Material and platforms
#
# - Material will always be accessible at https://github.com/vigji/python-ance-2025
#
# - Lectures material and assignments will be in the form of Jupyter Notebooks

# %% [markdown]
# **Platforms:**
# - **Google Colab** for the first part (online, no installation required)
# - **Local Python installation** for the second part (you'll get instructions)

# %% [markdown]
# **Required accounts:**
# - **Google** account for Google Colab
# - **GitHub** account for exercises, later

# %% [markdown]
# ### Course organization
#
# - The course will be organized in two modules.
# - Each module: 4-5 x lectures (2h)
# - Each lecture: frontal lecture + hands-on coding

# %% [markdown]
# ### Syllabus

# %% [markdown]
# Full syllabus at https://github.com/vigji/python-cimec-2025
#
# - module 0: the fundamentals
# - module 1: working with data in Python

# %% [markdown]
# ### Goals of the course

# %% [markdown]
# Learn the basics of Python - lingo and conceptual framework more than memorizing syntax!

# %% [markdown]
# You won't know everything but you'll now how to keep learning

# %% [markdown]
# ### Feedback
#
# - No experience teaching this course online
# - We will try to go slowly - if you don't understand something, it's likely my fault  🦥
# - Feedbacks and suggestions are welcome any time!

# %% [markdown]
# And now, without further ado..

# %% [markdown]
# ...What is Python?

# %% [markdown]
# ### Python

# %% [markdown]
# <span style="color:indianred">General purpose</span>, <span style="color:indianred">high level</span> programming language

# %% [markdown]
# Created in the early '90s by Guido van Rossum

# %% [markdown]
# Open-source + wide adoption --> massive number of open-source libraries

# %% [markdown]
# Named after the Monty Python's Flying Circus British TV show (not the animal)

# %% [markdown]
# ![Monty Python meme](https://media.giphy.com/media/TVupcr33Jpg7C/giphy.gif)

# %% [markdown]
# ### General purpose language
#
# - wide range of applications (science, web, desktop applications, games, business...)
# - support object-oriented programming, but also functional programming (arcane words that will soon make sense)
# - used literally anywhere: Google, NASA, Meta, Reddit, Netflix, JP Morgan, Pixar...

# %% [markdown]
# ### Interpreted language
#
# - Python (like MATLAB or R) is an <span style="color:indianred">interpreted language</span>
# - Opposed to e.g. C, which is a <span style="color:indianred">compiled language</span>
#
# (...typically...)

# %% [markdown]
# **Compiled language**: all the instructions of the program are translated to machine code before usage
#  - slow to compile, but fast to run
#  - broadly speaking, less user-friendly and harder to debug
#  - code has to be compiled on every different target OS

# %% [markdown]
# **Interpreted language**: each line of code is sent to an <span style="color:indianred">interpreter</span> that send instructions to the processor (using compiled code) and gives the response back
#  - slower than compiled code (usually)
#  - user friendly and easier to interact with
#  - code works across platforms as long as we use the same interpreter

# %% [markdown]
# ### Massive number of packages

# %% [markdown]
#  - very large (and quite geek) community
#  - literally tens of thousands of packages to do pretty much anything...

# %% [markdown]
# ...included plotting geek comics:

# %%
# Show geek comics:
import xkcd
from imageio.v2 import imread
from matplotlib import pyplot as plt

link = xkcd.Comic(353).getImageLink()  # get image link from number
plt.figure(figsize=(4, 4))  # plot image
plt.imshow(imread(link), cmap="gray")
plt.show()

# %% [markdown]
# ### Python vs. R vs. Excel vs STATA

# %% [markdown]
# **Python:**
#
# - general-purpose language: not just stats, but scripting, web, automation, ML…
# - huge ecosystem for data & science (NumPy, pandas, SciPy, scikit-learn, PyTorch…)
# - very good for data pipelines and integration with other tools
# - some friction with environments / versions (conda, venv, etc.); needs a bit of setup
# - open-source, massive community, lots of tutorials and examples

# %% [markdown]
# **Excel**:
# - extremely accessible: almost everyone has used it at least once
# - great for small tables, quick checks, manual data cleaning and simple plots
# - point-and-click workflow, but fragile and hard to reproduce or version-control
# - formulas can become opaque; error-prone for complex analyses
# - not suited for large datasets, automation, or serious software engineering

# %% [markdown]
# **R**:
#  - have not really tried, so can't speak too much
#  - overall, more focused on statistics: very good libraries for statistical models, Bayesian analyses, bioinformatics...
#  - more restricted in scope than Python

# %% [markdown]
# **STATA:**
#
# - again, no experience on my side, but from what i get...
# - integrated, menu-driven stats package with its own scripting language
# - strong in some field (econometrics, epidemiology...)
# - commercial, less flexible and extensible than Python/R, smaller ecosystem

# %% [markdown]
# ### Python: a _lingua franca_

# %% [markdown]
# As of 2025 Python can be considered the English of programming languages

# %% [markdown]
# You can get pretty much everywhere around computers just talking Python!

# %% [markdown]
# ### Python & APIs

# %% [markdown]
# Many, many tools and websites offer <span style="color:indianred">APIs</span> (Application Programming Interfaces). Many are not Python-specific, but it is easy to work with them in Python. With APIs we can:
#  - download data from servers
#  - publish content online
#  - interact with other software / databases
#  - ...

# %% [markdown]
# A small example:

# %%
import wikipedia

wikipedia.summary("Rovereto", sentences=1)
# Out:
# 'Rovereto (Italian pronunciation: [roveˈreːto]; "wood of sessile oaks"; locally: Roveredo) is a city and comune in Trentino in northern Italy, located in the Vallagarina valley of the Adige River.'

# %% [markdown]
# ### Coding with LLMs

# %% [markdown]
# - The quality of code from LLMs depend on availability of training data, and there is a lot of Python around!
# - Increasing number of tools for programming with LLMs (Copilot, Cursor...)
